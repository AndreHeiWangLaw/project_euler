# %%
"""

The four adjacent digits in the 1000-digit number that have the greatest product are 9*9*8*9 = 5832.

...

Find the thirteen adjacent digits in the 1000-digit number that have the greatest product. What is the value of this product?

"""

# %%
# POC

def largest_adj_product(num):

    # left, right window?
    left = 0
    right = left+num # under 1000

    while right <= 1000:
        return None




print(largest_adj_product(4))

# %%
# educated guess:
# 1. If there is a 0, then skip cuz X*0 = 0
# 2. Largest product is also largest sum (assuming no 0)

# POC

def largest_adj_product(num, digits):

    # left, right window?
    left = 0
    right = left+num # under 1000

    check_max = 0

    while left <= len(str(digits))-num:
        #print(str(digits)[left])
        product = 1
        for i in range(left, right):
            product *= int(str(digits)[i])
        check_max = max(check_max, product)
        left += 1
        right += 1

    return check_max

digits = ...
#digits = 73167176531330624919
print(largest_adj_product(4, digits))
# works

# %%
# scaling

def largest_adj_product(num, digits):

    # left, right window?
    left = 0
    right = left+num # under 1000
    check_max = 0

    while left <= len(str(digits))-num:
        product = 1
        for i in range(left, right):
            product *= int(str(digits)[i])
        check_max = max(check_max, product)
        left += 1
        right += 1
    return check_max

digits = ...
print(largest_adj_product(13, digits))
# solved
